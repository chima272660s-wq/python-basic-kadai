# %%
import random
var = random.randint(1, 100)
if var % 3 == 0:
  print("fizz")
elif var % 5 == 0:
  print("buzz")
elif var % 3 == 0 and var % 5 == 0:
  print("fizzbuzz")
else:
  print(var)
# Out:
# 58
